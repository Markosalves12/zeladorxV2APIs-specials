# %%
import requests
import pandas as pd

# %% [markdown]
# # Login

# %%
url = "http://127.0.0.1:9000/api/".replace("\\","/")

# %%
username="zeladorx@zeladorx.com.br"
password="BETpet1516%"

body = {
    "username":username,
    "password":password
}

# %%
response = requests.post("http://127.0.0.1:9000/api/login", body)

# %%
response.json()
# Out:
# {'token': '92ca37bb8f53bb9a8fbaefad1155c6ab55677c11',
#  'id_random': '6uW6BnjPFHyd',
#  'user_id': 1,
#  'username': 'zeladorx',
#  'email': 'zeladorx@zeladorx.com.br',
#  'is_superuser': True}

# %% [markdown]
# # Auth

# %%
headers = {
    "Authorization": f"Token {response.json()['token']}"
}

# %% [markdown]
# # Codigos de permissão disponiveis para uso

# %% [markdown]
# # lista de permissoes de especiais disponiveis

# %%
# os endpointe desse software estao elencados em api/permissions/ListPermissionsJardinagem/
# esses codigos sao uteis para o desnevolvevodor desenvover aplicacoes
response = requests.get("http://127.0.0.1:9000/api/permissions/ListPermissionsEspecials/", headers=headers)
df = pd.DataFrame(response.json())
display(df)
# Out:
#     id     id_random                                Permissions
# 0    1  wEhwIDMJ7WBv             270: Pode criar novas empresas
# 1    2  gpMmVA8nLLZk                  271: Pode editar empresas
# 2    3  0zAkXYEfbLfG              272: Pode visualizar empresas
# 3    4  lui6kRkfJxFV                 273: Pode excluir empresas
# 4    5  oj3KmoCBav7K            274: Pode desmobilizar empresas
# 5    6  qCr37H7FIc4A              275: Pode reabilitar empresas
# 6    7  zGo2L2iCiQ9Y      300: Pode editar permissões especiais
# 7    8  fFuk8AOS1HFM  301: Pode visualizar permissões especiais
# 8    9  ohqOLSfNeMmN             340: Pode criar novas unidades
# 9   10  51AA6UknQYAk                  341: Pode editar unidades
# 10  11  61ZR8usJCxES              342: Pode visualizar unidades
# 11  12  y97d4r9YZJKl                 343: Pode excluir unidades
# 12  13  npFioYx3kVFn            344: Pode desmobilizar unidades
# 13  14  Vg7AqZ528xIO              345: Pode reabilitar unidades
